# %% [markdown]
# ### Imports

# %%
from hfsql_guide.settings.paths import DATA_DIR, PARQUET_DIR, BLACKLISTED_TABLES, FAILED_TABLES
from concurrent.futures import ThreadPoolExecutor, TimeoutError
from hfsql_guide.settings.credentials import dsn, user, passwd
import pandas as pd
import pypyodbc
import warnings
import sys

TIMEOUT_SECONDS = 3 * 60   # 3 minutes

# %% [markdown]
# ### Code

# %%
# list of tables to export
tables = pd.read_excel(DATA_DIR / 'Tables_name.xlsx').iloc(axis=1)[0].tolist()

# %%
# remember to set up the connection in ODBC Data Source Administrator 64 bit
connection_string = (
    f"DSN={dsn};"
    f"UID={user};"
    f"PWD={passwd};"
)

# %%
def log_failed(table: str, reason: str):
    """Append failed table info to the log."""
    with FAILED_TABLES.open("a", encoding="utf8") as f:
        f.write(f"{table}  ---  {reason}\n")

def run_query_with_timeout(query: str, connection_string: str, timeout: int):
    """
    Runs a query in a separate thread, creating its OWN connection
    to prevent "zombie" hangs.
    """
    
    def _run_query_in_thread():
        """This function runs in the isolated thread."""
        conn_thread = None
        try:
            conn_thread = pypyodbc.connect(connection_string, autocommit=True)
            

            df = pd.read_sql(query, conn_thread, dtype="object")  # pyright: ignore[reportArgumentType]
            return df
        finally:
            if conn_thread:
                conn_thread.close()

    with ThreadPoolExecutor(max_workers=1) as executor:
        future = executor.submit(_run_query_in_thread)
        return future.result(timeout=timeout)

with open(BLACKLISTED_TABLES, 'r', encoding='utf8') as f:
    blacklist = [line.strip() for line in f if line.strip()]

with open(FAILED_TABLES, 'r', encoding='utf8') as f:
    already_failed = [line.split('  ---  ')[0] for line in f if line.strip()]

try:
    existing_files = set(f.stem for f in PARQUET_DIR.glob("*.parquet"))
    print(f"{len(existing_files)} .parquet files found.")
except FileNotFoundError:
    print("Nonexistent PARQUET_DIR, all files will be created.")
    existing_files = set()
# Out:
# 125 .parquet files found.

# %%
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

conn = None

try:
    conn = pypyodbc.connect(connection_string, autocommit=True)
    print("Database connection established.")

    for i, table in enumerate(tables, start=1):
        print(f"Table {i} of {len(tables)}")
        if table in existing_files:
            print(f"    Skipping table {i}, .parquet file already exists.")
            continue
        if table in already_failed:
            print(f"    Skipping previously failed table: {i}")
            continue
        if table in blacklist:
            print(f"    Skipping blacklisted table: {i}")
            continue
        try:  
            query = f"SELECT * FROM {table}"

            try:
                df = run_query_with_timeout(query, connection_string, TIMEOUT_SECONDS)
            except TimeoutError:
                print(f"    Timeout for {table}", file=sys.stderr)
                log_failed(table, "timeout")
                continue

            df = df.astype('string')  # convert all columns to string dtype to avoid type issues
            df = df.replace(['', ' ', 'NULL'], pd.NA) # replace empty strings and 'NULL' with NaN
            df.to_parquet(PARQUET_DIR / f"{table}.parquet", index=False)          

        except Exception as e:
            print(f"    An error occurred: {e}", file=sys.stderr)
            log_failed(table, str(e))
            continue

    print("Data export completed successfully.")

except pypyodbc.Error as e:
    print(f"Database connection error: {e}", file=sys.stderr)

except Exception as e:
    print(f"    An unexpected error occurred: {e}", file=sys.stderr)        

finally:
    if conn:
        conn.close()
        print("Database connection closed.")
# Out:
# Database connection established.
# Table 1 of 169
#     Skipping table 1, .parquet file already exists.
# Table 2 of 169
#     Skipping table 2, .parquet file already exists.
# Table 3 of 169
#     Skipping table 3, .parquet file already exists.
# Table 4 of 169
#     Skipping table 4, .parquet file already exists.
# Table 5 of 169
#     Skipping table 5, .parquet file already exists.
# Table 6 of 169
#     Skipping table 6, .parquet file already exists.
# Table 7 of 169
#     Skipping table 7, .parquet file already exists.
# Table 8 of 169
#     Skipping table 8, .parquet file already exists.
# Table 9 of 169
#     Timeout for ADM_IngresosEgresos
# Table 10 of 169
#     Skipping previously failed table: 10
# Table 11 of 169
#     Skipping table 11, .parquet file already exists.
# Table 12 of 169
#     Skipping previously failed table: 12
# Table 13 of 169
#     Skipping table 13, .parquet file already exists.
# Table 14 of 169
#     Skipping table 14, .parquet file already exists.
# Table 15 of 169
#     Skipping table 15, .parquet file already exists.
# Table 16 of 169
#     Skipping table 16, .parquet file already exists.
# Table 17 of 169
#     Skipping table 17, .parquet file already exists.
# Table 18 of 169
#     Skipping table 18, .parquet file already exists.
# Table 19 of 169
#     Skipping blacklisted table: 19
# Table 20 of 169
#     Skipping table 20, .parquet file already exists.
# Table 21 of 169
#     Skipping table 21, .parquet file already exists.
# Table 22 of 169
#     Skipping table 22, .parquet file already exists.
# Table 23 of 169
#     Skipping table 23, .parquet file already exists.
# Table 24 of 169
#     Skipping table 24, .parquet file already exists.
# Table 25 of 169
#     Skipping table 25, .parquet file already exists.
# Table 26 of 169
#     Skipping table 26, .parquet file already exists.
# Table 27 of 169
#     Skipping previously failed table: 27
# Table 28 of 169
#     Skipping table 28, .parquet file already exists.
# Table 29 of 169
#     Skipping table 29, .parquet file already exists.
# Table 30 of 169
#     Skipping blacklisted table: 30
# Table 31 of 169
#     Skipping table 31, .parquet file already exists.
# Table 32 of 169
#     Skipping table 32, .parquet file already exists.
# Table 33 of 169
#     Skipping table 33, .parquet file already exists.
# Table 34 of 169
#     Skipping blacklisted table: 34
# Table 35 of 169
#     Skipping blacklisted table: 35
# Table 36 of 169
#     Skipping previously failed table: 36
# Table 37 of 169
#     Skipping table 37, .parquet file already exists.
# Table 38 of 169
#     Skipping table 38, .parquet file already exists.
# Table 39 of 169
#     Skipping previously failed table: 39
# Table 40 of 169
#     Skipping blacklisted table: 40
# Table 41 of 169
#     Skipping previously failed table: 41
# Table 42 of 169
#     Skipping table 42, .parquet file already exists.
# Table 43 of 169
#     Skipping table 43, .parquet file already exists.
# Table 44 of 169
#     Skipping table 44, .parquet file already exists.
# Table 45 of 169
#     Skipping previously failed table: 45
# Table 46 of 169
#     Skipping table 46, .parquet file already exists.
# Table 47 of 169
#     Skipping table 47, .parquet file already exists.
# Table 48 of 169
#     Skipping table 48, .parquet file already exists.
# Table 49 of 169
#     Skipping previously failed table: 49
# Table 50 of 169
#     Skipping previously failed table: 50
# Table 51 of 169
#     Skipping table 51, .parquet file already exists.
# Table 52 of 169
#     Skipping table 52, .parquet file already exists.
# Table 53 of 169
#     Skipping table 53, .parquet file already exists.
# Table 54 of 169
#     Skipping previously failed table: 54
# Table 55 of 169
#     Skipping previously failed table: 55
# Table 56 of 169
#     Skipping table 56, .parquet file already exists.
# Table 57 of 169
#     Skipping table 57, .parquet file already exists.
# Table 58 of 169
#     Skipping table 58, .parquet file already exists.
# Table 59 of 169
#     Skipping table 59, .parquet file already exists.
# Table 60 of 169
#     Skipping table 60, .parquet file already exists.
# Table 61 of 169
#     Skipping table 61, .parquet file already exists.
# Table 62 of 169
#     Skipping table 62, .parquet file already exists.
# Table 63 of 169
#     Skipping table 63, .parquet file already exists.
# Table 64 of 169
#     Skipping table 64, .parquet file already exists.
# Table 65 of 169
#     Skipping table 65, .parquet file already exists.
# Table 66 of 169
#     Skipping previously failed table: 66
# Table 67 of 169
#     Skipping table 67, .parquet file already exists.
# Table 68 of 169
#     Skipping table 68, .parquet file already exists.
# Table 69 of 169
#     Skipping table 69, .parquet file already exists.
# Table 70 of 169
#     Skipping table 70, .parquet file already exists.
# Table 71 of 169
#     Skipping table 71, .parquet file already exists.
# Table 72 of 169
#     Skipping table 72, .parquet file already exists.
# Table 73 of 169
#     Skipping table 73, .parquet file already exists.
# Table 74 of 169
#     Skipping table 74, .parquet file already exists.
# Table 75 of 169
#     Skipping table 75, .parquet file already exists.
# Table 76 of 169
#     Skipping table 76, .parquet file already exists.
# Table 77 of 169
#     Skipping blacklisted table: 77
# Table 78 of 169
#     Skipping previously failed table: 78
# Table 79 of 169
#     Skipping table 79, .parquet file already exists.
# Table 80 of 169
#     Skipping table 80, .parquet file already exists.
# Table 81 of 169
#     Skipping table 81, .parquet file already exists.
# Table 82 of 169
#     Skipping table 82, .parquet file already exists.
# Table 83 of 169
#     Skipping previously failed table: 83
# Table 84 of 169
#     Skipping blacklisted table: 84
# Table 85 of 169
#     Skipping table 85, .parquet file already exists.
# Table 86 of 169
#     Skipping table 86, .parquet file already exists.
# Table 87 of 169
#     Skipping table 87, .parquet file already exists.
# Table 88 of 169
#     Skipping table 88, .parquet file already exists.
# Table 89 of 169
#     Skipping blacklisted table: 89
# Table 90 of 169
#     Skipping blacklisted table: 90
# Table 91 of 169
#     Skipping previously failed table: 91
# Table 92 of 169
#     Skipping blacklisted table: 92
# Table 93 of 169
#     Skipping table 93, .parquet file already exists.
# Table 94 of 169
#     Skipping previously failed table: 94
# Table 95 of 169
#     Skipping table 95, .parquet file already exists.
# Table 96 of 169
#     Skipping table 96, .parquet file already exists.
# Table 97 of 169
#     Skipping table 97, .parquet file already exists.
# Table 98 of 169
#     Skipping previously failed table: 98
# Table 99 of 169
#     Skipping table 99, .parquet file already exists.
# Table 100 of 169
#     Skipping table 100, .parquet file already exists.
# Table 101 of 169
#     Skipping blacklisted table: 101
# Table 102 of 169
#     Skipping table 102, .parquet file already exists.
# Table 103 of 169
#     Skipping table 103, .parquet file already exists.
# Table 104 of 169
#     Skipping previously failed table: 104
# Table 105 of 169
#     Skipping blacklisted table: 105
# Table 106 of 169
#     Skipping table 106, .parquet file already exists.
# Table 107 of 169
#     Skipping table 107, .parquet file already exists.
# Table 108 of 169
#     Skipping table 108, .parquet file already exists.
# Table 109 of 169
#     Skipping previously failed table: 109
# Table 110 of 169
#     Skipping table 110, .parquet file already exists.
# Table 111 of 169
#     Skipping previously failed table: 111
# Table 112 of 169
#     Skipping blacklisted table: 112
# Table 113 of 169
#     Skipping table 113, .parquet file already exists.
# Table 114 of 169
#     Skipping table 114, .parquet file already exists.
# Table 115 of 169
#     Skipping table 115, .parquet file already exists.
# Table 116 of 169
#     Skipping table 116, .parquet file already exists.
# Table 117 of 169
#     Skipping table 117, .parquet file already exists.
# Table 118 of 169
#     Skipping table 118, .parquet file already exists.
# Table 119 of 169
#     Skipping table 119, .parquet file already exists.
# Table 120 of 169
#     Skipping table 120, .parquet file already exists.
# Table 121 of 169
#     Skipping previously failed table: 121
# Table 122 of 169
#     Skipping table 122, .parquet file already exists.
# Table 123 of 169
#     Skipping table 123, .parquet file already exists.
# Table 124 of 169
#     Skipping table 124, .parquet file already exists.
# Table 125 of 169
#     Skipping table 125, .parquet file already exists.
# Table 126 of 169
#     Skipping table 126, .parquet file already exists.
# Table 127 of 169
#     Skipping table 127, .parquet file already exists.
# Table 128 of 169
#     Skipping table 128, .parquet file already exists.
# Table 129 of 169
#     Skipping previously failed table: 129
# Table 130 of 169
#     Skipping table 130, .parquet file already exists.
# Table 131 of 169
#     Skipping table 131, .parquet file already exists.
# Table 132 of 169
#     Skipping table 132, .parquet file already exists.
# Table 133 of 169
#     Skipping table 133, .parquet file already exists.
# Table 134 of 169
#     Skipping table 134, .parquet file already exists.
# Table 135 of 169
#     Skipping table 135, .parquet file already exists.
# Table 136 of 169
#     Skipping table 136, .parquet file already exists.
# Table 137 of 169
#     Skipping table 137, .parquet file already exists.
# Table 138 of 169
#     Skipping table 138, .parquet file already exists.
# Table 139 of 169
#     Skipping table 139, .parquet file already exists.
# Table 140 of 169
#     Skipping previously failed table: 140
# Table 141 of 169
#     Skipping table 141, .parquet file already exists.
# Table 142 of 169
#     Skipping blacklisted table: 142
# Table 143 of 169
#     Skipping blacklisted table: 143
# Table 144 of 169
#     Skipping table 144, .parquet file already exists.
# Table 145 of 169
#     Skipping table 145, .parquet file already exists.
# Table 146 of 169
#     Skipping table 146, .parquet file already exists.
# Table 147 of 169
#     Skipping table 147, .parquet file already exists.
# Table 148 of 169
#     Skipping table 148, .parquet file already exists.
# Table 149 of 169
#     Skipping table 149, .parquet file already exists.
# Table 150 of 169
#     Skipping table 150, .parquet file already exists.
# Table 151 of 169
#     Skipping table 151, .parquet file already exists.
# Table 152 of 169
#     Skipping table 152, .parquet file already exists.
# Table 153 of 169
#     Skipping table 153, .parquet file already exists.
# Table 154 of 169
#     Skipping table 154, .parquet file already exists.
# Table 155 of 169
#     Skipping table 155, .parquet file already exists.
# Table 156 of 169
#     Skipping table 156, .parquet file already exists.
# Table 157 of 169
#     Skipping table 157, .parquet file already exists.
# Table 158 of 169
#     Skipping table 158, .parquet file already exists.
# Table 159 of 169
#     Skipping table 159, .parquet file already exists.
# Table 160 of 169
#     Skipping table 160, .parquet file already exists.
# Table 161 of 169
#     Skipping blacklisted table: 161
# Table 162 of 169
#     Skipping table 162, .parquet file already exists.
# Table 163 of 169
#     Skipping table 163, .parquet file already exists.
# Table 164 of 169
#     Skipping table 164, .parquet file already exists.
# Table 165 of 169
#     Skipping table 165, .parquet file already exists.
# Table 166 of 169
#     Skipping previously failed table: 166
# Table 167 of 169
#     Skipping previously failed table: 167
# Table 168 of 169
#     Skipping previously failed table: 168
# Table 169 of 169
#     An error occurred: Execution failed on sql 'SELECT * FROM nan': ('HY090', '[HY090] ¿Qué sucedió?\r\nError en el código SQL de la consulta <SQLODBC>. No se puede inicializar la consulta.\r\nArchivo nan desconocido\r\nError detectado:\r\nSELECT * FROM >>>>nan<<<<\r\n\r\nCódigo de error: 28000002\r\nNivel: error fatal\r\n\r\nMódulo: wd300sql64.dll (01A305067  - 30.0.562.0)\r\n\r\nInformación de depuración:\r\nIEWD300SQL=1.21\r\nModule=<WD300SQL>\r\nVersion=<30.0.562.0>\r\nInformación adicional:\r\nEIT_LOGICALTABLENAME : <nan>\r\nEIT_POSITION_ERREUR : <0\t14\t0\t16>')
# Data export completed successfully.
# Database connection closed.
